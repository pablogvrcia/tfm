# %%
# !git clone https://github.com/modelscope/DiffSynth-Studio.git
# !cd DiffSynth-Studio && pip install -e .
# Out:
# Cloning into 'DiffSynth-Studio'...
# remote: Enumerating objects: 7484, done.
# remote: Counting objects: 100% (96/96), done.
# remote: Compressing objects: 100% (72/72), done.
# remote: Total 7484 (delta 32), reused 64 (delta 20), pack-reused 7388 (from 2)
# Receiving objects: 100% (7484/7484), 14.84 MiB | 10.22 MiB/s, done.
# Resolving deltas: 100% (4902/4902), done.
# Obtaining file:///mnt/HHD8TB/shared_HHD/tfm_pablo/tfm/code/DiffSynth-Studio
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: torch>=2.0.0 in /mnt/HHD8TB/shared_HHD/tfm_pablo/tfm/code/venv/lib/python3.11/site-packages (from diffsynth==1.1.8) (2.9.0)
# Requirement already satisfied: torchvision in /mnt/HHD8TB/shared_HHD/tfm_pablo/tfm/code/venv/lib/python3.11/site-packages (from diffsynth==1.1.8) (0.24.0)
# Requirement already satisfied: transformers in /mnt/HHD8TB/shared_HHD/tfm_pablo/tfm/code/venv/lib/python3.11/site-packages (from diffsynth==1.1.8) (4.57.1)
# Requirement already satisfied: imageio in /mnt/HHD8TB/shared_HHD/tfm_pablo/tfm/code/venv/lib/python3.11/site-packages (from diffsynth==1.1.8) (2.37.2)
# Requirement already satisfied: safetensors in /mnt/HHD8TB/shared_HHD/tfm_pablo/tfm/code/venv/lib/python3.11/site-packages (from diffsynth==1.1.8) (0.6.2)
# Collecting einops (from diffsynth==1.1.8)
#   Obtaining dependency information for einops from https://files.pythonhosted.org/packages/87/62/9773de14fe6c45c23649e98b83231fffd7b9892b6cf863251dc2afa73643/einops-0.8.1-py3-none-any.whl.metadata
#   Downloading einops-0.8.1-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: sentencepiece in /mnt/HHD8TB/shared_HHD/tfm_pablo/tfm/code/venv/lib/python3.11/site-packages (from diffsynth==1.1.8) (0.2.1)
# Collecting protobuf (from diffsynth==1.1.8)
#   Obtaining dependency information for protobuf from https://files.pythonhosted.org/packages/21/51/0b1cbad62074439b867b4e04cc09b93f6699d78fd191bed2bbb44562e077/protobuf-6.33.0-cp39-abi3-manylinux2014_x86_64.whl.metadata
#   Downloading protobuf-6.33.0-cp39-abi3-manylinux2014_x86_64.whl.metadata (593 bytes)
# Collecting modelscope (from diffsynth==1.1.8)
#   Obtaining dependency information for modelscope from https://files.pythonhosted.org/packages/bb/a8/26bda5fdbcb9ad18c52d81961520b3b55bc082969a46dc8b18495ef7726b/modelscope-1.31.0-py3-none-any.whl.metadata
#   Downloading modelscope-1.31.0-py3-none-any.whl.metadata (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.4/40.4 kB 2.9 MB/s eta 0:00:00
# Requirement already satisfied: ftfy in /mnt/HHD8TB/shared_HHD/tfm_pablo/tfm/code/venv/lib/python3.11/site-packages (from diffsynth==1.1.8) (6.3.1)
# Collecting pynvml (from diffsynth==1.1.8)
#   Obtaining dependency information for pynvml from https://files.pythonhosted.org/packages/d7/4a/cac76c174bb439a0c46c9a4413fcbea5c6cabfb01879f7bbdb9fdfaed76c/pynvml-13.0.1-py3-none-any.whl.metadata
#   Downloading pynvml-13.0.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting pandas (from diffsynth==1.1.8)
#   Obtaining dependency information for pandas from https://files.pythonhosted.org/packages/bf/c9/63f8d545568d9ab91476b1818b4741f521646cbdd151c6efebf40d6de6f7/pandas-2.3.3-cp311-cp311-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata
#   Downloading pandas-2.3.3-cp311-cp311-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (91 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.2/91.2 kB 5.7 MB/s eta 0:00:00
# Requirement already satisfied: accelerate in /mnt/HHD8TB/shared_HHD/tfm_pablo/tfm/code/venv/lib/python3.11/site-packages (from diffsynth==1.1.8) (1.11.0)
# Collecting peft (from diffsynth==1.1.8)
#   Obtaining dependency information for peft from https://files.pythonhosted.org/packages/49/fe/a2da1627aa9cb6310b6034598363bd26ac301c4a99d21f415b1b2855891e/peft-0.17.1-py3-none-any.whl.metadata
#   Downloading peft-0.17.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: filelock in /mnt/HHD8TB/shared_HHD/tfm_pablo/tfm/code/venv/lib/python3.11/site-packages (from torch>=2.0.0->diffsynth==1.1.8) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /mnt/HHD8TB/shared_HHD/tfm_pablo/tfm/code/venv/lib/python3.11/site-packages (from torch>=2.0.0->diffsynth==1.1.8) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in /mnt/HHD8TB/shared_HHD/tfm_pablo/tfm/code/venv/lib/python3.11/site-packages (from torch>=2.0.0->diffsynth==1.1.8) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /mnt/HHD8TB/shared_HHD/tfm_pablo/tfm/code/venv/lib/python3.11/site-packages (from torch>=2.0.0->diffsynth==1.1.8) (3.5)
# Requirement already satisfied: jinja2 in /mnt/HHD8TB/shared_HHD/tfm_pablo/tfm/code/venv/lib/python3.11/site-packages (from torch>=2.0.0->diffsynth==1.1.8) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /mnt/HHD8TB/shared_HHD/tfm_pablo/tfm/code/venv/lib/python3.11/site-packages (from torch>=2.0.0->diffsynth==1.1.8) (2025.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /mnt/HHD8TB/shared_HHD/tfm_pablo/tfm/code/venv/lib/python3.11/site-packages (from torch>=2.0.0->diffsynth==1.1.8) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /mnt/HHD8TB/shared_HHD/tfm_pablo/tfm/code/venv/lib/python3.11/site-packages (from torch>=2.0.0->diffsynth==1.1.8) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /mnt/HHD8TB/shared_HHD/tfm_pablo/tfm/code/venv/lib/python3.11/site-packages (from torch>=2.0.0->diffsynth==1.1.8) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /mnt/HHD8TB/shared_HHD/tfm_pablo/tfm/code/venv/lib/python3.11/site-packages (from torch>=2.0.0->diffsynth==1.1.8) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /mnt/HHD8TB/shared_HHD/tfm_pablo/tfm/code/venv/lib/python3.11/site-packages (from torch>=2.0.0->diffsynth==1.1.8) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /mnt/HHD8TB/shared_HHD/tfm_pablo/tfm/code/venv/lib/python3.11/site-packages (from torch>=2.0.0->diffsynth==1.1.8) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /mnt/HHD8TB/shared_HHD/tfm_pablo/tfm/code/venv/lib/python3.11/site-packages (from torch>=2.0.0->diffsynth==1.1.8) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /mnt/HHD8TB/shared_HHD/tfm_pablo/tfm/code/venv/lib/python3.11/site-packages (from torch>=2.0.0->diffsynth==1.1.8) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /mnt/HHD8TB/shared_HHD/tfm_pablo/tfm/code/venv/lib/python3.11/site-packages (from torch>=2.0.0->diffsynth==1.1.8) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /mnt/HHD8TB/shared_HHD/tfm_pablo/tfm/code/venv/lib/python3.11/site-packages (from torch>=2.0.0->diffsynth==1.1.8) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /mnt/HHD8TB/shared_HHD/tfm_pablo/tfm/code/venv/lib/python3.11/site-packages (from torch>=2.0.0->diffsynth==1.1.8) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /mnt/HHD8TB/shared_HHD/tfm_pablo/tfm/code/venv/lib/python3.11/site-packages (from torch>=2.0.0->diffsynth==1.1.8) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /mnt/HHD8TB/shared_HHD/tfm_pablo/tfm/code/venv/lib/python3.11/site-packages (from torch>=2.0.0->diffsynth==1.1.8) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /mnt/HHD8TB/shared_HHD/tfm_pablo/tfm/code/venv/lib/python3.11/site-packages (from torch>=2.0.0->diffsynth==1.1.8) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /mnt/HHD8TB/shared_HHD/tfm_pablo/tfm/code/venv/lib/python3.11/site-packages (from torch>=2.0.0->diffsynth==1.1.8) (1.13.1.3)
# Requirement already satisfied: triton==3.5.0 in /mnt/HHD8TB/shared_HHD/tfm_pablo/tfm/code/venv/lib/python3.11/site-packages (from torch>=2.0.0->diffsynth==1.1.8) (3.5.0)
# Requirement already satisfied: numpy>=1.17 in /mnt/HHD8TB/shared_HHD/tfm_pablo/tfm/code/venv/lib/python3.11/site-packages (from accelerate->diffsynth==1.1.8) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /mnt/HHD8TB/shared_HHD/tfm_pablo/tfm/code/venv/lib/python3.11/site-packages (from accelerate->diffsynth==1.1.8) (25.0)
# Requirement already satisfied: psutil in /mnt/HHD8TB/shared_HHD/tfm_pablo/tfm/code/venv/lib/python3.11/site-packages (from accelerate->diffsynth==1.1.8) (7.1.3)
# Requirement already satisfied: pyyaml in /mnt/HHD8TB/shared_HHD/tfm_pablo/tfm/code/venv/lib/python3.11/site-packages (from accelerate->diffsynth==1.1.8) (6.0.3)
# Requirement already satisfied: huggingface_hub>=0.21.0 in /mnt/HHD8TB/shared_HHD/tfm_pablo/tfm/code/venv/lib/python3.11/site-packages (from accelerate->diffsynth==1.1.8) (0.36.0)
# Requirement already satisfied: wcwidth in /mnt/HHD8TB/shared_HHD/tfm_pablo/tfm/code/venv/lib/python3.11/site-packages (from ftfy->diffsynth==1.1.8) (0.2.14)
# Requirement already satisfied: pillow>=8.3.2 in /mnt/HHD8TB/shared_HHD/tfm_pablo/tfm/code/venv/lib/python3.11/site-packages (from imageio->diffsynth==1.1.8) (12.0.0)
# Collecting imageio-ffmpeg (from imageio->diffsynth==1.1.8)
#   Obtaining dependency information for imageio-ffmpeg from https://files.pythonhosted.org/packages/a0/2d/43c8522a2038e9d0e7dbdf3a61195ecc31ca576fb1527a528c877e87d973/imageio_ffmpeg-0.6.0-py3-none-manylinux2014_x86_64.whl.metadata
#   Using cached imageio_ffmpeg-0.6.0-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: requests>=2.25 in /mnt/HHD8TB/shared_HHD/tfm_pablo/tfm/code/venv/lib/python3.11/site-packages (from modelscope->diffsynth==1.1.8) (2.32.5)
# Requirement already satisfied: setuptools in /mnt/HHD8TB/shared_HHD/tfm_pablo/tfm/code/venv/lib/python3.11/site-packages (from modelscope->diffsynth==1.1.8) (65.5.0)
# Requirement already satisfied: tqdm>=4.64.0 in /mnt/HHD8TB/shared_HHD/tfm_pablo/tfm/code/venv/lib/python3.11/site-packages (from modelscope->diffsynth==1.1.8) (4.67.1)
# Requirement already satisfied: urllib3>=1.26 in /mnt/HHD8TB/shared_HHD/tfm_pablo/tfm/code/venv/lib/python3.11/site-packages (from modelscope->diffsynth==1.1.8) (2.5.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /mnt/HHD8TB/shared_HHD/tfm_pablo/tfm/code/venv/lib/python3.11/site-packages (from pandas->diffsynth==1.1.8) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas->diffsynth==1.1.8)
#   Obtaining dependency information for pytz>=2020.1 from https://files.pythonhosted.org/packages/81/c4/34e93fe5f5429d7570ec1fa436f1986fb1f00c3e0f43a589fe2bbcd22c3f/pytz-2025.2-py2.py3-none-any.whl.metadata
#   Downloading pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas->diffsynth==1.1.8)
#   Obtaining dependency information for tzdata>=2022.7 from https://files.pythonhosted.org/packages/5c/23/c7abc0ca0a1526a0774eca151daeb8de62ec457e77262b66b359c3c7679e/tzdata-2025.2-py2.py3-none-any.whl.metadata
#   Downloading tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting nvidia-ml-py>=12.0.0 (from pynvml->diffsynth==1.1.8)
#   Obtaining dependency information for nvidia-ml-py>=12.0.0 from https://files.pythonhosted.org/packages/7f/96/d6d25a4c307d6645f4a9b91d620c0151c544ad38b5e371313a87d2761004/nvidia_ml_py-13.580.82-py3-none-any.whl.metadata
#   Downloading nvidia_ml_py-13.580.82-py3-none-any.whl.metadata (9.6 kB)
# Requirement already satisfied: regex!=2019.12.17 in /mnt/HHD8TB/shared_HHD/tfm_pablo/tfm/code/venv/lib/python3.11/site-packages (from transformers->diffsynth==1.1.8) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /mnt/HHD8TB/shared_HHD/tfm_pablo/tfm/code/venv/lib/python3.11/site-packages (from transformers->diffsynth==1.1.8) (0.22.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /mnt/HHD8TB/shared_HHD/tfm_pablo/tfm/code/venv/lib/python3.11/site-packages (from huggingface_hub>=0.21.0->accelerate->diffsynth==1.1.8) (1.2.0)
# Requirement already satisfied: six>=1.5 in /mnt/HHD8TB/shared_HHD/tfm_pablo/tfm/code/venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->diffsynth==1.1.8) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /mnt/HHD8TB/shared_HHD/tfm_pablo/tfm/code/venv/lib/python3.11/site-packages (from requests>=2.25->modelscope->diffsynth==1.1.8) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /mnt/HHD8TB/shared_HHD/tfm_pablo/tfm/code/venv/lib/python3.11/site-packages (from requests>=2.25->modelscope->diffsynth==1.1.8) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /mnt/HHD8TB/shared_HHD/tfm_pablo/tfm/code/venv/lib/python3.11/site-packages (from requests>=2.25->modelscope->diffsynth==1.1.8) (2025.10.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /mnt/HHD8TB/shared_HHD/tfm_pablo/tfm/code/venv/lib/python3.11/site-packages (from sympy>=1.13.3->torch>=2.0.0->diffsynth==1.1.8) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /mnt/HHD8TB/shared_HHD/tfm_pablo/tfm/code/venv/lib/python3.11/site-packages (from jinja2->torch>=2.0.0->diffsynth==1.1.8) (3.0.3)
# Downloading einops-0.8.1-py3-none-any.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.4/64.4 kB 10.1 MB/s eta 0:00:00
# Downloading modelscope-1.31.0-py3-none-any.whl (5.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 11.2 MB/s eta 0:00:0000:0100:01
# Downloading pandas-2.3.3-cp311-cp311-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (12.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 11.3 MB/s eta 0:00:0000:0100:01
# Downloading peft-0.17.1-py3-none-any.whl (504 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 504.9/504.9 kB 11.0 MB/s eta 0:00:00a 0:00:01
# Downloading protobuf-6.33.0-cp39-abi3-manylinux2014_x86_64.whl (323 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 323.2/323.2 kB 12.0 MB/s eta 0:00:00
# Downloading pynvml-13.0.1-py3-none-any.whl (28 kB)
# Downloading nvidia_ml_py-13.580.82-py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.0/49.0 kB 15.1 MB/s eta 0:00:00
# Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 509.2/509.2 kB 11.6 MB/s eta 0:00:00a 0:00:01
# Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 347.8/347.8 kB 11.8 MB/s eta 0:00:00
# Downloading imageio_ffmpeg-0.6.0-py3-none-manylinux2014_x86_64.whl (29.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.5/29.5 MB 10.8 MB/s eta 0:00:0000:0100:01
# Building wheels for collected packages: diffsynth
#   Building editable for diffsynth (pyproject.toml) ... done
#   Created wheel for diffsynth: filename=diffsynth-1.1.8-0.editable-py3-none-any.whl size=7161 sha256=966191c2c88ebc14185d1df2f4d59d82958d4fb185e40f4b9473e46fe7ac76f9
#   Stored in directory: /tmp/pip-ephem-wheel-cache-fyk0v57_/wheels/e2/86/6d/1207f2608ce2c1d0d1976a71ab3dc0582a8f5e969618a587c8
# Successfully built diffsynth
# Installing collected packages: pytz, nvidia-ml-py, tzdata, pynvml, protobuf, imageio-ffmpeg, einops, pandas, modelscope, peft, diffsynth
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ltx-video 0.1.2 requires huggingface-hub~=0.25.2, but you have huggingface-hub 0.36.0 which is incompatible.
# Successfully installed diffsynth-1.1.8 einops-0.8.1 imageio-ffmpeg-0.6.0 modelscope-1.31.0 nvidia-ml-py-13.580.82 pandas-2.3.3 peft-0.17.1 protobuf-6.33.0 pynvml-13.0.1 pytz-2025.2 tzdata-2025.2
#
# [notice] A new release of pip is available: 23.2.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
# !pip install modelscope
# Out:
# Requirement already satisfied: modelscope in ./venv/lib/python3.11/site-packages (1.31.0)
# Requirement already satisfied: filelock in ./venv/lib/python3.11/site-packages (from modelscope) (3.20.0)
# Requirement already satisfied: requests>=2.25 in ./venv/lib/python3.11/site-packages (from modelscope) (2.32.5)
# Requirement already satisfied: setuptools in ./venv/lib/python3.11/site-packages (from modelscope) (65.5.0)
# Requirement already satisfied: tqdm>=4.64.0 in ./venv/lib/python3.11/site-packages (from modelscope) (4.67.1)
# Requirement already satisfied: urllib3>=1.26 in ./venv/lib/python3.11/site-packages (from modelscope) (2.5.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./venv/lib/python3.11/site-packages (from requests>=2.25->modelscope) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in ./venv/lib/python3.11/site-packages (from requests>=2.25->modelscope) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in ./venv/lib/python3.11/site-packages (from requests>=2.25->modelscope) (2025.10.5)
#
# [notice] A new release of pip is available: 23.2.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip
